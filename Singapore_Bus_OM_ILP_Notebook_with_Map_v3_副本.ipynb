# %% [markdown]
# # Singapore Bus Network Operations Management Analysis and ILP Optimization
#
# This notebook uses the Singapore bus dataset to perform an **Operations Management (OM)** analysis and a **linear programming (LP)** optimization model.
#
# ## Objectives
# 1. Understand the network structure and service characteristics.
# 2. Apply OM concepts such as **process analysis, capacity, bottleneck, utilization, and waste identification**.
# 3. Build a runnable **ILP model** to allocate additional weekday departures under a limited bus-hour budget.
#
# > Dataset source : Kaggle - Singapore Bus Data (Land Transport Authority)

# %%
# ================================
# 1) Import libraries 
# ================================
# Standard data analysis and optimization libraries

import os
import re
import math
import zipfile
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import milp, Bounds, LinearConstraint

plt.rcParams["figure.figsize"] = (10, 6)
pd.set_option("display.max_columns", 100)
pd.set_option("display.float_format", lambda x: f"{x:,.3f}")

# %%
# =============================================
# 2) Locate and extract dataset 
# =============================================


CANDIDATE_DIRS = [
    Path("."),
    Path("."),
]

ZIP_CANDIDATES = [
    Path("archive (2).zip"),
    Path("archive (2).zip"),
]

routes_file = None
services_file = None
stops_file = None

for folder in CANDIDATE_DIRS:
    r = folder / "bus_routes.csv"
    s = folder / "bus_services.csv"
    b = folder / "bus_stops.csv"
    if r.exists() and s.exists() and b.exists():
        routes_file, services_file, stops_file = r, s, b
        break

if routes_file is None:
    for zip_path in ZIP_CANDIDATES:
        if zip_path.exists():
            extract_dir = zip_path.parent / "bus_dataset_extracted"
            extract_dir.mkdir(exist_ok=True)
            with zipfile.ZipFile(zip_path, "r") as zf:
                zf.extractall(extract_dir)
            routes_file = extract_dir / "bus_routes.csv"
            services_file = extract_dir / "bus_services.csv"
            stops_file = extract_dir / "bus_stops.csv"
            break

if routes_file is None:
    raise FileNotFoundError("Could not find bus_routes.csv / 无法找到 bus_routes.csv")

print("Routes file / 路线文件:", routes_file)
print("Services file / 服务文件:", services_file)
print("Stops file / 站点文件:", stops_file)
# Out:
# Routes file / 路线文件: bus_dataset_extracted/bus_routes.csv
# Services file / 服务文件: bus_dataset_extracted/bus_services.csv
# Stops file / 站点文件: bus_dataset_extracted/bus_stops.csv

# %%
# ======================================
# 3) Load data
# ======================================
# Read the three core files.

routes = pd.read_csv(routes_file)
services = pd.read_csv(services_file)
stops = pd.read_csv(stops_file)

print("routes shape:", routes.shape)
print("services shape:", services.shape)
print("stops shape:", stops.shape)

display(routes.head())
display(services.head())
display(stops.head())
# Out:
# routes shape: (26317, 13)
# services shape: (729, 12)
# stops shape: (5021, 6)
#    Unnamed: 0 ServiceNo Operator  Direction  StopSequence BusStopCode  \
# 0           0        10     SBST          1             1       75009
# 1           1        10     SBST          1             2       76059
# 2           2        10     SBST          1             3       76069
# 3           3        10     SBST          1             4       96289
# 4           4        10     SBST          1             5       96109
#
#    Distance WD_FirstBus WD_LastBus SAT_FirstBus SAT_LastBus SUN_FirstBus  \
# 0     0.000        0500       2300         0500        2300         0500
# 1     0.600        0502       2302         0502        2302         0502
# 2     1.100        0504       2304         0504        2304         0503
# 3     2.300        0508       2308         0508        2309         0507
# 4     2.700        0509       2310         0509        2311         0508
#
#   SUN_LastBus
# 0        2300
# 1        2302
# 2        2304
# 3        2308
# 4        2309
#    Unnamed: 0 ServiceNo Operator  Direction Category  OriginCode  \
# 0           0       118      GAS          1    TRUNK  65,009.000
# 1           1       118      GAS          2    TRUNK  97,009.000
# 2           2      118A      GAS          1    TRUNK  65,199.000
# 3           3      118B      GAS          1    TRUNK  96,111.000
# 4           4       119      GAS          1    TRUNK  65,009.000
#
#    DestinationCode AM_Peak_Freq AM_Offpeak_Freq PM_Peak_Freq PM_Offpeak_Freq  \
# 0       97,009.000        06-08           08-15        10-12           11-15
# 1       65,009.000           10           10-12        05-11           10-15
# 2       96,119.000        14-16               -            -               -
# 3       65,191.000            -               -           30               -
# 4       65,009.000        16-08           18-12        17-12           15-17
#
#         LoopDesc
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4  Hougang St 21
#    Unnamed: 0  BusStopCode       RoadName             Description  Latitude  \
# 0           0          481   Woodlands Rd  BT PANJANG TEMP BUS PK     1.384
# 1           1         1012    Victoria St     Hotel Grand Pacific     1.297
# 2           2         1013    Victoria St         St. Joseph's Ch     1.298
# 3           3         1019    Victoria St         Bras Basah Cplx     1.297
# 4           4         1029  Nth Bridge Rd   Cosmic Insurance Bldg     1.297
#
#    Longitude
# 0    103.758
# 1    103.853
# 2    103.853
# 3    103.853
# 4    103.854

# %%
# ======================================
# 4) Basic cleaning
# ======================================
# - Remove unnamed index columns
# - Standardize key code columns to string
# - Clean obvious data issues

def drop_unnamed(df):
    return df.loc[:, ~df.columns.str.contains("^Unnamed")].copy()

routes = drop_unnamed(routes)
services = drop_unnamed(services)
stops = drop_unnamed(stops)

routes["BusStopCode"] = routes["BusStopCode"].astype(str)
stops["BusStopCode"] = stops["BusStopCode"].astype(str)

services["ServiceNo"] = services["ServiceNo"].astype(str)
routes["ServiceNo"] = routes["ServiceNo"].astype(str)

# Standardize some code columns
for col in ["OriginCode", "DestinationCode"]:
    if col in services.columns:
        services[col] = services[col].astype("Int64").astype(str)

print(routes.info())
print(services.info())
print(stops.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26317 entries, 0 to 26316
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ServiceNo     26317 non-null  object
#  1   Operator      26317 non-null  object
#  2   Direction     26317 non-null  int64
#  3   StopSequence  26317 non-null  int64
#  4   BusStopCode   26317 non-null  object
#  5   Distance      26312 non-null  float64
#  6   WD_FirstBus   26317 non-null  object
#  7   WD_LastBus    26317 non-null  object
#  8   SAT_FirstBus  26317 non-null  object
#  9   SAT_LastBus   26317 non-null  object
#  10  SUN_FirstBus  26317 non-null  object
#  11  SUN_LastBus   26317 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ServiceNo        729 non-null    object
#  1   Operator         729 non-null    object
#  2   Direction        729 non-null    int64
#  3   Category         729 non-null    object
#  4   OriginCode       729 non-null    object
#  5   DestinationCode  729 non-null    object
#  6   AM_Peak_Freq     729 non-null    object
#  7   AM_Offpeak_Freq  729 non-null    object
#  8   PM_Peak_Freq     729 non-null    object
#  9   PM_Offpeak_Freq  728 non-null    object
#  10  LoopDesc         263 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 62.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5021 entries, 0 to 5020
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   BusStopCode  5021 non-null   object
#  1   RoadName     5021 non-null   object
#  2   Description  5021 non-null   object
#  3   Latitude     5021 non-null   float64
#  4   Longitude    5021 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 196.3+ KB
# None

# %%
# ======================================================
# 5) Helper functions
# ======================================================
# We need to parse timetable values and frequency ranges such as '10-15'.

def parse_hhmm(value):
    if pd.isna(value):
        return np.nan
    s = str(value).strip()
    if s in {"-", "", "nan", "None"}:
        return np.nan
    s = s.zfill(4)
    if not re.fullmatch(r"\d{4}", s):
        return np.nan
    hh = int(s[:2])
    mm = int(s[2:])
    return hh * 60 + mm

def service_span(first_bus, last_bus):
    if pd.isna(first_bus) or pd.isna(last_bus):
        return np.nan
    span = last_bus - first_bus
    # If the service crosses midnight
    if span < 0:
        span += 24 * 60
    return span

def parse_freq_range(value):
    if pd.isna(value):
        return np.nan
    s = str(value).strip()
    if s in {"-", "", "nan", "None"}:
        return np.nan
    nums = re.findall(r"\d+", s)
    if len(nums) == 0:
        return np.nan
    nums = [float(x) for x in nums]
    return float(np.mean(nums))

def zscore(series):
    std = series.std(ddof=0)
    if pd.isna(std) or std == 0:
        return pd.Series(np.zeros(len(series)), index=series.index)
    return (series - series.mean()) / std

# %%
# ======================================================
# 6) Derive route-level summary
# ======================================================
# Aggregate stop-level route records into route-direction level metrics.

# Parse weekday timetable
routes["WD_FirstBus_min"] = routes["WD_FirstBus"].apply(parse_hhmm)
routes["WD_LastBus_min"] = routes["WD_LastBus"].apply(parse_hhmm)
routes["WD_ServiceSpan_min"] = routes.apply(
    lambda x: service_span(x["WD_FirstBus_min"], x["WD_LastBus_min"]), axis=1
)

# Route-direction summary
route_summary = (
    routes.groupby(["ServiceNo", "Direction", "Operator"], as_index=False)
    .agg(
        n_stops=("StopSequence", "max"),
        route_distance_km=("Distance", "max"),
        wd_first_min=("WD_FirstBus_min", "min"),
        wd_last_min=("WD_LastBus_min", "max"),
        wd_service_span_min=("WD_ServiceSpan_min", "max"),
        unique_stops=("BusStopCode", "nunique"),
    )
)

# Parse weekday frequencies from bus_services
services["AM_Peak_headway_min"] = services["AM_Peak_Freq"].apply(parse_freq_range)
services["AM_Offpeak_headway_min"] = services["AM_Offpeak_Freq"].apply(parse_freq_range)
services["PM_Peak_headway_min"] = services["PM_Peak_Freq"].apply(parse_freq_range)
services["PM_Offpeak_headway_min"] = services["PM_Offpeak_Freq"].apply(parse_freq_range)

services["avg_wd_headway_min"] = services[
    ["AM_Peak_headway_min", "AM_Offpeak_headway_min", "PM_Peak_headway_min", "PM_Offpeak_headway_min"]
].mean(axis=1, skipna=True)

service_summary = services[
    ["ServiceNo", "Direction", "Category", "OriginCode", "DestinationCode", "avg_wd_headway_min"]
].copy()

# Merge route structure + service information
route_summary = route_summary.merge(
    service_summary,
    on=["ServiceNo", "Direction"],
    how="left"
)

# Estimate trips and cycle time
ASSUMED_SPEED_KMPH = 18   # English: average commercial speed
DWELL_MIN_PER_STOP = 0.35 # English: average dwell time
route_summary["one_way_trip_time_min"] = (
    route_summary["route_distance_km"] / ASSUMED_SPEED_KMPH * 60
    + route_summary["n_stops"] * DWELL_MIN_PER_STOP
)

route_summary["baseline_daily_trips"] = (
    route_summary["wd_service_span_min"] / route_summary["avg_wd_headway_min"]
)

# Replace impossible values
route_summary["baseline_daily_trips"] = route_summary["baseline_daily_trips"].replace([np.inf, -np.inf], np.nan)
route_summary["baseline_daily_trips"] = route_summary["baseline_daily_trips"].fillna(route_summary["baseline_daily_trips"].median())

display(route_summary.head())
print(route_summary.shape)
# Out:
#   ServiceNo  Direction Operator  n_stops  route_distance_km  wd_first_min  \
# 0        10          1     SBST       74             31.700       300.000
# 1        10          2     SBST       74             31.900       360.000
# 2       100          1     SBST       55             23.600       330.000
# 3       100          2     SBST       54             23.300       360.000
# 4      100A          1     SBST       13              4.700       399.000
#
#    wd_last_min  wd_service_span_min  unique_stops Category OriginCode  \
# 0    1,440.000            1,081.000            74    TRUNK      75009
# 1    1,440.000            1,107.000            74    TRUNK      16009
# 2    1,440.000            1,096.000            55    TRUNK      66009
# 3    1,440.000            1,094.000            54    TRUNK      11009
# 4    1,195.000              776.000            13    TRUNK      66009
#
#   DestinationCode  avg_wd_headway_min  one_way_trip_time_min  \
# 0           16009              11.750                131.567
# 1           75009              12.625                132.233
# 2           11009              12.375                 97.917
# 3           66009              10.375                 96.567
# 4           81089              22.167                 20.217
#
#    baseline_daily_trips
# 0                92.000
# 1                87.683
# 2                88.566
# 3               105.446
# 4                35.008
# (727, 15)

# %%
# ======================================================
# 7) Create OM indicators
# ======================================================
# English:
# Build route-level indicators aligned with OM concepts:
# - capacity proxy
# - bottleneck score
# - route complexity

# A proxy for offered service output
route_summary["offered_stop_visits_per_day"] = (
    route_summary["baseline_daily_trips"] * route_summary["n_stops"]
)

# Complexity score
route_summary["complexity_score"] = (
    zscore(route_summary["route_distance_km"]) * 0.40
    + zscore(route_summary["n_stops"]) * 0.35
    + zscore(route_summary["one_way_trip_time_min"]) * 0.25
)

# Bottleneck score:
# routes with long trip time and long headway are more likely to be operationally stressed
route_summary["bottleneck_score"] = (
    zscore(route_summary["one_way_trip_time_min"]) * 0.50
    + zscore(route_summary["avg_wd_headway_min"].fillna(route_summary["avg_wd_headway_min"].median())) * 0.30
    + zscore(route_summary["n_stops"]) * 0.20
)

# Simple utilization proxy:
# more offered stop visits divided by trip time => stronger throughput intensity
route_summary["throughput_intensity"] = (
    route_summary["offered_stop_visits_per_day"] / route_summary["one_way_trip_time_min"]
)

route_summary = route_summary.sort_values("complexity_score", ascending=False).reset_index(drop=True)

display(route_summary[[
    "ServiceNo", "Direction", "Operator", "n_stops", "route_distance_km",
    "wd_service_span_min", "avg_wd_headway_min", "one_way_trip_time_min",
    "baseline_daily_trips", "complexity_score", "bottleneck_score"
]].head(15))
# Out:
#    ServiceNo  Direction Operator  n_stops  route_distance_km  \
# 0        858          1     SMRT       83             73.500
# 1        518          1      GAS       91             59.900
# 2        502          1     SBST       89             59.600
# 3         24          1     SBST      103             51.700
# 4        966          1     SMRT       63             63.600
# 5         53          1     SBST       87             53.000
# 6        70M          1     SBST      105             42.000
# 7        160          1     SBST       84             48.700
# 8        NR7          1     SMRT      106             41.100
# 9         36          1      GAS       67             52.700
# 10        89          1     SBST       95             43.400
# 11       NR1          1     SMRT       93             43.200
# 12        63          1     SBST      103             38.900
# 13        61          1     SMRT       97             39.600
# 14      162M          1     SBST       97             39.000
#
#     wd_service_span_min  avg_wd_headway_min  one_way_trip_time_min  \
# 0             1,176.000               7.250                274.050
# 1             1,016.000              17.500                231.517
# 2             1,055.000              17.250                229.817
# 3             1,122.000              10.625                208.383
# 4             1,065.000              11.500                234.050
# 5             1,169.000               9.125                207.117
# 6               286.000              14.375                176.750
# 7             1,135.000              16.375                191.733
# 8                   NaN              29.000                174.100
# 9             1,122.000               9.125                199.117
# 10            1,113.000              12.000                177.917
# 11                  NaN              25.000                176.550
# 12            1,112.000              10.750                165.717
# 13            1,134.000              10.875                165.950
# 14              315.000              13.625                163.950
#
#     baseline_daily_trips  complexity_score  bottleneck_score
# 0                162.207             4.024             2.568
# 1                 58.057             3.386             2.534
# 2                 61.159             3.332             2.485
# 3                105.600             3.135             2.099
# 4                 92.609             3.080             2.065
# 5                128.110             2.913             1.874
# 6                 19.896             2.612             1.885
# 7                 69.313             2.609             1.946
# 8                 85.545             2.578             2.437
# 9                122.959             2.524             1.590
# 10                92.750             2.507             1.711
# 11                85.545             2.458             2.187
# 12               103.442             2.396             1.591
# 13               104.276             2.324             1.542
# 14                23.119             2.290             1.626

# %%
# ======================================================
# 8) OM descriptive analysis
# ======================================================
# English: Identify long routes, high-stop routes, and potential bottlenecks.

top_distance = route_summary.nlargest(10, "route_distance_km")[
    ["ServiceNo", "Direction", "Operator", "route_distance_km", "n_stops", "one_way_trip_time_min"]
]

top_stops = route_summary.nlargest(10, "n_stops")[
    ["ServiceNo", "Direction", "Operator", "n_stops", "route_distance_km", "one_way_trip_time_min"]
]

top_bottleneck = route_summary.nlargest(10, "bottleneck_score")[
    ["ServiceNo", "Direction", "Operator", "avg_wd_headway_min", "one_way_trip_time_min", "bottleneck_score"]
]

print("Top 10 longest routes")
display(top_distance)

print("Top 10 highest-stop routes")
display(top_stops)

print("Top 10 potential bottlenecks")
display(top_bottleneck)
# Out:
# Top 10 longest routes
#    ServiceNo  Direction Operator  route_distance_km  n_stops  \
# 0        858          1     SMRT             73.500       83
# 4        966          1     SMRT             63.600       63
# 1        518          1      GAS             59.900       91
# 2        502          1     SBST             59.600       89
# 5         53          1     SBST             53.000       87
# 9         36          1      GAS             52.700       67
# 3         24          1     SBST             51.700      103
# 7        160          1     SBST             48.700       84
# 31        27          1     SBST             44.500       55
# 61        35          1     SBST             43.500       36
#
#     one_way_trip_time_min
# 0                 274.050
# 4                 234.050
# 1                 231.517
# 2                 229.817
# 5                 207.117
# 9                 199.117
# 3                 208.383
# 7                 191.733
# 31                167.583
# 61                157.600
# Top 10 highest-stop routes
#    ServiceNo  Direction Operator  n_stops  route_distance_km  \
# 8        NR7          1     SMRT      106             41.100
# 6        70M          1     SBST      105             42.000
# 3         24          1     SBST      103             51.700
# 12        63          1     SBST      103             38.900
# 13        61          1     SMRT       97             39.600
# 14      162M          1     SBST       97             39.000
# 15        51          1     SBST       97             37.800
# 10        89          1     SBST       95             43.400
# 17      961C          2     SMRT       95             37.400
# 19        51          2     SBST       95             36.000
#
#     one_way_trip_time_min
# 8                 174.100
# 6                 176.750
# 3                 208.383
# 12                165.717
# 13                165.950
# 14                163.950
# 15                159.950
# 10                177.917
# 17                157.917
# 19                153.250
# Top 10 potential bottlenecks
#     ServiceNo  Direction Operator  avg_wd_headway_min  one_way_trip_time_min  \
# 45        36B          1      GAS              54.333                154.267
# 16         4N          1     SBST              40.000                168.733
# 0         858          1     SMRT               7.250                274.050
# 1         518          1      GAS              17.500                231.517
# 2         502          1     SBST              17.250                229.817
# 8         NR7          1     SMRT              29.000                174.100
# 398       67W          1     SMRT              77.000                 66.317
# 25         2N          1     SBST              40.000                156.300
# 32         3N          1     SBST              40.000                153.867
# 33         5N          1     SBST              40.000                153.867
#
#      bottleneck_score
# 45              2.722
# 16              2.597
# 0               2.568
# 1               2.534
# 2               2.485
# 8               2.437
# 398             2.395
# 25              2.391
# 32              2.305
# 33              2.305

# %%
# ======================================================
# 9) Visualizations
# ======================================================
# English: A few core charts for report and presentation.

# Chart 1: distance distribution
plt.figure()
route_summary["route_distance_km"].hist(bins=30)
plt.title("Distribution of Route Distance (km)")
plt.xlabel("Route distance (km)")
plt.ylabel("Count")
plt.show()

# Chart 2: scatter of stops vs trip time
plt.figure()
plt.scatter(route_summary["n_stops"], route_summary["one_way_trip_time_min"], alpha=0.6)
plt.title("Stops vs One-way Trip Time")
plt.xlabel("Number of stops")
plt.ylabel("One-way trip time (min)")
plt.show()

# Chart 3: top bottleneck routes
plot_df = route_summary.nlargest(10, "bottleneck_score").sort_values("bottleneck_score")
labels = plot_df["ServiceNo"] + "-" + plot_df["Direction"].astype(str)

plt.figure()
plt.barh(labels, plot_df["bottleneck_score"])
plt.title("Top Bottleneck Routes")
plt.xlabel("Bottleneck score")
plt.ylabel("Route")
plt.show()

# %% [markdown]
# ## Singapore map-based route visualization
#
# This section adds geographic visualizations using bus stop latitude/longitude.
#
# Included views：
# 1. **All bus stops map**
# 2. **Single route movement line**
# 3. **Top bottleneck routes on one Singapore map**

# %%
# ======================================================
# 9A) Build geo-merged route data
# ======================================================
# English:
# Merge route stop sequence with stop latitude/longitude so that we can draw route paths.

# Optional dependency check
try:
    import folium
    from folium.plugins import MarkerCluster
except ImportError:
    raise ImportError("Please install folium first: pip install folium")

# Standardize stop code before merge
stops_geo = stops.copy()
stops_geo['BusStopCode'] = stops_geo['BusStopCode'].astype(str).str.replace(r'\.0$', '', regex=True)

route_geo = routes.merge(
    stops_geo[['BusStopCode', 'Latitude', 'Longitude', 'RoadName', 'Description']],
    on='BusStopCode',
    how='left'
)

# Remove rows without coordinates
route_geo = route_geo.dropna(subset=['Latitude', 'Longitude']).copy()

print('route_geo shape:', route_geo.shape)
print(route_geo[['ServiceNo', 'Direction', 'StopSequence', 'BusStopCode', 'Latitude', 'Longitude']].head())
# Out:
# route_geo shape: (23708, 19)
#   ServiceNo  Direction  StopSequence BusStopCode  Latitude  Longitude
# 0        10          1             1       75009     1.354    103.943
# 1        10          1             2       76059     1.353    103.942
# 2        10          1             3       76069     1.349    103.942
# 3        10          1             4       96289     1.340    103.948
# 4        10          1             5       96109     1.337    103.951
# /Users/huanghaojie/Desktop/PE6012/Student Learning Predict/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# ======================================================
# 9B) All bus stops map
# ======================================================
# English:
# Plot bus stops as clustered markers on a Singapore-centered map.

sg_center = [stops_geo['Latitude'].mean(), stops_geo['Longitude'].mean()]
all_stops_map = folium.Map(location=sg_center, zoom_start=11, tiles='CartoDB positron')
marker_cluster = MarkerCluster(name='Bus Stops').add_to(all_stops_map)

# Sample markers to keep rendering light in notebook
sample_stops = stops_geo.dropna(subset=['Latitude', 'Longitude']).sample(
    n=min(1200, len(stops_geo.dropna(subset=['Latitude', 'Longitude']))),
    random_state=42
)

for _, row in sample_stops.iterrows():
    popup_text = f"{row['BusStopCode']} - {row.get('Description', '')}"
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=3,
        popup=popup_text,
        fill=True,
        fill_opacity=0.7
    ).add_to(marker_cluster)

all_stops_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a66239ae3af9672ec2208f7e4b435a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a66239ae3af9672ec2208f7e4b435a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a66239ae3af9672ec2208f7e4b435a3 = L.map(
#                 &quot;map_7a66239ae3af9672ec2208f7e4b435a3&quot;,
#                 {
#                     center: [1.351256626960191, 103.82263678765158],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfc5519604b2c97dd464513e34b183b0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfc5519604b2c97dd464513e34b183b0.addTo(map_7a66239ae3af9672ec2208f7e4b435a3);
#
#
#             var marker_cluster_696f18b40a4700020ca5f98c1d0ac8b4 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_9511b204edb50bd308e2e43a1d75303c = L.circleMarker(
#                 [1.34425795644531, 103.720124877254],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_696f18b40a4700020ca5f98c1d0ac8b4);
#
#
#         var popup_07f4205aeb67e6396c728d872f56d796 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8be54f3335f69b508ecc3648ee957488 = $(`&lt;div id=&quot;html_8be54f3335f69b508ecc3648ee957488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;28091 - Lakeside Stn&lt;/div&gt;`)[0];
#                 popup_07f4205aeb67e6396c728d872f56d796.setContent(html_8be54f3335f69b508ecc3648ee957488);
#
#
#
#         circle_marker_9511b204edb50bd308e2e43a1d75303c.bindPopup(popup_07f4205aeb67e6396c728d872f56d796)
#         ;
#
#
#
#
#             var circle_marker_e1b41a522ccf06e93d19076e12a64b14 = L.circleMarker(
#                 [1.27568194286532, 103.81914854048932],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_696f18b40a4700020ca5f98c1d0ac8b4);
#
#
#         var popup_2266faae6eccabbc82d9e132780ed889 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5a1b26586a5e77608bce7632257a3eb = $(`&lt;div id=&quot;html_e5a1b26586a5e77608bce7632257a3eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;14271 - Al-Amin Mque&lt;/div&gt;`)[0];
#                 popup_2266faae6eccabbc82d9e132780ed889.setContent(html_e5a1b26586a5e77608bce7632257a3eb);
#
#
#
#         circle_marker_e1b41a522ccf06e93d19076e12a64b14.bindPopup(popup_2266faae6eccabbc82d9e132780ed889)
#         ;
#
#
#
#
#             var circle_marker_e740a761f006ef704731b1209b5cb0be = L.circleMarker(
#                 [1.374401340713, 103.88353995121632],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;

# %%
# ======================================================
# 9C) Single route movement line
# ======================================================
# English:
# Choose one route and direction, then draw the ordered stop-to-stop polyline.
# By default, we show the highest bottleneck-score route if route_summary exists.

def draw_route_map(service_no, direction=1, zoom_start=12):
    subset = route_geo[(route_geo['ServiceNo'].astype(str) == str(service_no)) & 
                       (route_geo['Direction'] == direction)].sort_values('StopSequence')
    if subset.empty:
        raise ValueError(f'No route data found for ServiceNo={service_no}, Direction={direction}')

    center = [subset['Latitude'].mean(), subset['Longitude'].mean()]
    m = folium.Map(location=center, zoom_start=zoom_start, tiles='CartoDB positron')

    # Draw ordered path
    points = subset[['Latitude', 'Longitude']].values.tolist()
    folium.PolyLine(points, weight=5, opacity=0.8, popup=f'Route {service_no} Dir {direction}').add_to(m)

    # Add start/end markers
    first_row = subset.iloc[0]
    last_row = subset.iloc[-1]
    folium.Marker(
        [first_row['Latitude'], first_row['Longitude']],
        popup=f"Start: {first_row['Description']} ({first_row['BusStopCode']})",
        tooltip='Start',
        icon=folium.Icon(icon='play', prefix='fa')
    ).add_to(m)
    folium.Marker(
        [last_row['Latitude'], last_row['Longitude']],
        popup=f"End: {last_row['Description']} ({last_row['BusStopCode']})",
        tooltip='End',
        icon=folium.Icon(icon='stop', prefix='fa', color='red')
    ).add_to(m)

    # Show a few intermediate stops
    step = max(1, len(subset) // 12)
    for _, row in subset.iloc[::step].iterrows():
        folium.CircleMarker(
            [row['Latitude'], row['Longitude']],
            radius=4,
            popup=f"{row['StopSequence']}: {row['Description']} ({row['BusStopCode']})",
            fill=True,
            fill_opacity=0.8
        ).add_to(m)
    return m

if 'route_summary' in globals() and 'bottleneck_score' in route_summary.columns and len(route_summary) > 0:
    example_row = route_summary.sort_values('bottleneck_score', ascending=False).iloc[0]
    example_service = example_row['ServiceNo']
    example_direction = int(example_row['Direction'])
else:
    example_service = route_geo['ServiceNo'].astype(str).iloc[0]
    example_direction = int(route_geo['Direction'].iloc[0])

print(f"Example route shown: ServiceNo={example_service}, Direction={example_direction}")
single_route_map = draw_route_map(example_service, example_direction)
single_route_map
# Out:
# Example route shown: ServiceNo=36B, Direction=1
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_365c8542789dd46d49eb1ccfd3f252c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_365c8542789dd46d49eb1ccfd3f252c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_365c8542789dd46d49eb1ccfd3f252c9 = L.map(
#                 &quot;map_365c8542789dd46d49eb1ccfd3f252c9&quot;,
#                 {
#                     center: [1.3058103014626095, 103.91387410064328],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c46e682012a5cc1257059b74e162249 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c46e682012a5cc1257059b74e162249.addTo(map_365c8542789dd46d49eb1ccfd3f252c9);
#
#
#             var poly_line_2947a54610ed822ac964d7d5d02cfa0a = L.polyline(
#                 [[1.31073016722066, 103.9329857782451], [1.30958474832555, 103.9295415420364], [1.30920003741893, 103.92781269211484], [1.30851455788092, 103.92471047692146], [1.30787614366531, 103.92111718654822], [1.3071917122941, 103.91764721757994], [1.30684575808096, 103.91574700260745], [1.30566306799291, 103.9110051545323], [1.30425139809964, 103.90773354554798], [1.30300441466613, 103.9059569060291], [1.30178441800843, 103.9009525469614], [1.3023783312326, 103.89900426571224], [1.3012419783155, 103.89745113021507], [1.30079999936599, 103.89740107761654], [1.30166304472072, 103.9011814962942], [1.30327282994495, 103.9058301337522], [1.30461834682389, 103.90783296450576], [1.30585304722559, 103.91059595623032], [1.3067937735779, 103.91498055803812], [1.30751338586806, 103.91754269765208], [1.30822971200422, 103.92151900444856], [1.30867772794032, 103.92426998119755], [1.30794833296674, 103.92628500000932]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_365c8542789dd46d49eb1ccfd3f252c9);
#
#
#         var popup_19366eba4333da6e1c1bc9dd2625ddad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce568492928253a5f940856ce5644a54 = $(`&lt;div id=&quot;html_ce568492928253a5f940856ce5644a54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route 36B Dir 1&lt;/div&gt;`)[0];
#                 popup_19366eba4333da6e1c1bc9dd2625ddad.setContent(html_ce568492928253a5f940856ce5644a54);
#
#
#
#         poly_line_2947a54610ed822ac964d7d5d02cfa0a.bindPopup(popup_19366eba4333da6e1c1bc9dd2625ddad)
#         ;
#
#
#
#
#             var marker_a4f9fa740df6da0c1290d7af055a87a9 = L.marker(
#                 [1.31073016722066, 103.9329857782451],
#                 {
# }
#             ).addTo(map_365c8542789dd46d49eb1ccfd3f252c9);
#
#
#             var icon_e2d3758313d6812560c9852c0eecd096 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;play&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_566d7f66b795c182278989c44e9658d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bb863e6af034e41c11464723fe1a073 = $(`&lt;div id=&quot;html_5bb863e6af034e41c11464723fe1a073&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start: Lagoon View (93049)&lt;/div&gt;`)[0];
#                 popup_566d7f66b795c182278989c44e9658d1.setContent(html_5bb863e6af034e41c11464723fe1a073);
#
#
#
#         marker_a4f9fa740df6da0c1290d7af055a87a9.bindPopup(popup_566d7f66b795c182278989c44e9658d1)
#         ;
#
#
#
#
#             marker_a4f9fa740df6da0c1290d7af055a87a9.bindTooltip(
#                 `&lt;div&gt;
#                      Start
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_a4f9fa740df6da0c1290d7af055a87a9.setIcon(icon_e2d3758313d6812560c9852c0eecd096);
#
#
#             var marker_64fc168e6cffdfc

# %%
# ======================================================
# 9D) Top bottleneck routes on Singapore map
# ======================================================
# Overlay several top bottleneck routes on one map for comparison.

from matplotlib import cm, colors

if 'route_summary' in globals() and 'bottleneck_score' in route_summary.columns:
    top_routes_map = folium.Map(location=sg_center, zoom_start=11, tiles='CartoDB positron')
    top_n = 5
    top_routes = route_summary.sort_values('bottleneck_score', ascending=False).head(top_n).copy()

    cmap = cm.get_cmap('tab10', top_n)
    for idx, (_, r) in enumerate(top_routes.iterrows()):
        s_no = str(r['ServiceNo'])
        d_no = int(r['Direction'])
        subset = route_geo[(route_geo['ServiceNo'].astype(str) == s_no) & 
                           (route_geo['Direction'] == d_no)].sort_values('StopSequence')
        if len(subset) < 2:
            continue
        hex_color = colors.to_hex(cmap(idx))
        pts = subset[['Latitude', 'Longitude']].values.tolist()
        folium.PolyLine(
            pts,
            weight=4,
            color=hex_color,
            opacity=0.85,
            tooltip=f"Service {s_no} Dir {d_no} | Bottleneck Score: {r['bottleneck_score']:.2f}"
        ).add_to(top_routes_map)

    top_routes[['ServiceNo', 'Direction', 'route_distance_km', 'n_stops', 'bottleneck_score']]
    top_routes_map
else:
    print('route_summary or bottleneck_score not found. Please run earlier OM analysis cells first.')
# Out:
# /var/folders/mq/42h_20dd6550fywpscjwzb_h0000gn/T/ipykernel_32504/424170801.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab10', top_n)

# %%
# ======================================================
# 9E) Export interactive maps
# ======================================================
# Save HTML map files so they can be opened separately or embedded in presentation material.

map_output_dir = Path('bus_outputs')
map_output_dir.mkdir(exist_ok=True)

all_stops_html = map_output_dir / 'singapore_bus_stops_map.html'
single_route_html = map_output_dir / f'singapore_route_{example_service}_dir_{example_direction}.html'

all_stops_map.save(str(all_stops_html))
single_route_map.save(str(single_route_html))
print('Saved:', all_stops_html)
print('Saved:', single_route_html)

if 'top_routes_map' in globals():
    top_routes_html = map_output_dir / 'singapore_top_bottleneck_routes_map.html'
    top_routes_map.save(str(top_routes_html))
    print('Saved:', top_routes_html)
# Out:
# Saved: bus_outputs/singapore_bus_stops_map.html
# Saved: bus_outputs/singapore_route_36B_dir_1.html
# Saved: bus_outputs/singapore_top_bottleneck_routes_map.html

# %% [markdown]
# ## Operations Management Interpretation
#
# ### 1. Process analysis
# A bus route can be treated as a service process:
# **dispatch → travel → stop servicing → arrival → turnaround**
#
# ### 2. Capacity
# For a route, capacity is constrained by:
# - service span
# - headway
# - trip time
#
# ### 3. Bottleneck
# Potential bottlenecks are routes with:
# - long one-way trip time
# - many stops
# - relatively infrequent weekday service
#
# ### 4. Lean waste
# Possible wastes include:
# - waiting
# - unnecessary route overlap
# - uneven workload (Mura)
# - overburden (Muri) on long routes

# %%
# ======================================================
# 10) Build ILP dataset
# ======================================================
# We now formulate a capacity-allocation ILP.
# Decision variable = additional weekday departures allocated to each route.

# Focus on routes with valid service data
lp_df = route_summary.copy()
lp_df = lp_df[
    lp_df["one_way_trip_time_min"].notna()
    & lp_df["baseline_daily_trips"].notna()
    & (lp_df["baseline_daily_trips"] > 0)
].copy()

# Select a manageable subset for optimization:
# choose top 25 routes by bottleneck score
lp_df = lp_df.nlargest(25, "bottleneck_score").copy().reset_index(drop=True)

# Priority score for extra departures:
# routes with higher bottleneck score and complexity get more benefit from extra departures
lp_df["priority_score"] = (
    0.6 * zscore(lp_df["bottleneck_score"])
    + 0.4 * zscore(lp_df["complexity_score"])
)

# Shift to positive coefficients for ILP maximization
lp_df["priority_score"] = lp_df["priority_score"] - lp_df["priority_score"].min() + 1

# Upper bound: allow at most 25% more trips than baseline
lp_df["max_additional_trips"] = np.ceil(lp_df["baseline_daily_trips"] * 0.25)

# Resource consumption of each extra trip:
# one extra departure consumes one one-way trip time
lp_df["trip_resource_hours"] = lp_df["one_way_trip_time_min"] / 60.0

# Total additional bus-hour budget (scenario parameter)
EXTRA_BUS_HOURS_BUDGET = 120

display(lp_df[[
    "ServiceNo", "Direction", "Operator", "baseline_daily_trips",
    "one_way_trip_time_min", "trip_resource_hours",
    "priority_score", "max_additional_trips"
]])
# Out:
#    ServiceNo  Direction Operator  baseline_daily_trips  one_way_trip_time_min  \
# 0        36B          1      GAS                10.656                154.267
# 1         4N          1     SBST                85.545                168.733
# 2        858          1     SMRT               162.207                274.050
# 3        518          1      GAS                58.057                231.517
# 4        502          1     SBST                61.159                229.817
# 5        NR7          1     SMRT                85.545                174.100
# 6        67W          1     SMRT                85.545                 66.317
# 7         2N          1     SBST                85.545                156.300
# 8         3N          1     SBST                85.545                153.867
# 9         5N          1     SBST                85.545                153.867
# 10       NR1          1     SMRT                85.545                176.550
# 11       67A          1     SMRT                13.857                 50.850
# 12        1N          1     SBST                85.545                140.783
# 13        24          1     SBST               105.600                208.383
# 14       966          1     SMRT                92.609                234.050
# 15       NR6          1     SMRT                85.545                152.783
# 16       NR5          1     SMRT                85.545                144.133
# 17       160          1     SBST                69.313                191.733
# 18       70M          1     SBST                19.896                176.750
# 19        53          1     SBST               128.110                207.117
# 20        89          1     SBST                92.750                177.917
# 21       NR2          1     SMRT                85.545                143.633
# 22      162M          1     SBST                23.119                163.950
# 23        6N          1     SBST                85.545                136.700
# 24        63          1     SBST               103.442                165.717
#
#     trip_resource_hours  priority_score  max_additional_trips
# 0                 2.571           3.093                 3.000
# 1                 2.812           3.112                22.000
# 2                 4.567           3.797                41.000
# 3                 3.859           3.478                15.000
# 4                 3.830           3.367                16.000
# 5                 2.902           2.973                22.000
# 6                 1.105           1.797                22.000
# 7                 2.605           2.623                22.000
# 8                 2.564           2.421                22.000
# 9                 2.564           2.421                22.000
# 10                2.943           2.474                22.000
# 11                0.848           1.176                 4.000
# 12                2.346           1.935                22.000
# 13                3.473           2.592                27.000
# 14                3.901           2.509                24.000
# 15                2.546           1.942                22.000
# 16                2.402           1.787                22.000
# 17                3.196           2.101                18.000
# 18                2.946           1.993                 5.000
# 19                3.452           2.096                33.000
# 20                2.965           1.638                24.000
# 21                2.394           1.111                22.000
# 22                2.732           1.396                 6.000
# 23                2.278           1.000                22.000
# 24                2.762           1.375                26.000

# %%
# ======================================================
# 11) Solve ILP model
# ======================================================
# English:
# Objective:
#   maximize Σ priority_i * additional_trips_i
# Subject to:
#   Σ resource_hours_i * additional_trips_i <= budget
#   0 <= additional_trips_i <= upper bound
#   additional_trips_i must be integers
#
# We use scipy.optimize.milp so that each added trip is an integer,
# which is more realistic for bus scheduling.
c = -lp_df["priority_score"].to_numpy(dtype=float)

# Linear resource constraint
A = np.array([lp_df["trip_resource_hours"].to_numpy(dtype=float)])
lb = np.array([-np.inf])
ub = np.array([EXTRA_BUS_HOURS_BUDGET], dtype=float)
constraints = LinearConstraint(A, lb, ub)

# Variable bounds
bounds = Bounds(
    lb=np.zeros(len(lp_df), dtype=float),
    ub=lp_df["max_additional_trips"].to_numpy(dtype=float)
)

# Integrality: 1 means integer variable
integrality = np.ones(len(lp_df), dtype=int)

result = milp(
    c=c,
    integrality=integrality,
    bounds=bounds,
    constraints=constraints
)

print("Optimization status:", result.message)
print("Optimal objective value:", -result.fun if result.success else None)
# Out:
# Optimization status: Optimization terminated successfully. (HiGHS Status 7: Optimal)
# Optimal objective value: 145.06801457617522

# %%
# ======================================================
# 12) Optimization results
# ======================================================
# Show how extra departures are allocated under the integer budgeted solution.


if result.success:
    lp_df["optimal_additional_trips"] = result.x.astype(int)
    lp_df["resource_used_hours"] = lp_df["optimal_additional_trips"] * lp_df["trip_resource_hours"]
    lp_df["new_total_trips"] = lp_df["baseline_daily_trips"] + lp_df["optimal_additional_trips"]

    cols = [
        "ServiceNo", "Direction", "Operator",
        "baseline_daily_trips", "optimal_additional_trips",
        "new_total_trips", "trip_resource_hours",
        "resource_used_hours", "priority_score"
    ]
    display(lp_df[cols].sort_values("optimal_additional_trips", ascending=False).head(15))

    print("Total resource used (hours):", lp_df["resource_used_hours"].sum())
    print("Total added trips:", int(lp_df["optimal_additional_trips"].sum()))
else:
    print("ILP did not solve successfully")
# Out:
#    ServiceNo  Direction Operator  baseline_daily_trips  \
# 6        67W          1     SMRT                85.545
# 1         4N          1     SBST                85.545
# 5        NR7          1     SMRT                85.545
# 11       67A          1     SMRT                13.857
# 0        36B          1      GAS                10.656
# 7         2N          1     SBST                85.545
# 15       NR6          1     SMRT                85.545
# 23        6N          1     SBST                85.545
# 22      162M          1     SBST                23.119
# 21       NR2          1     SMRT                85.545
# 20        89          1     SBST                92.750
# 19        53          1     SBST               128.110
# 18       70M          1     SBST                19.896
# 17       160          1     SBST                69.313
# 16       NR5          1     SMRT                85.545
#
#     optimal_additional_trips  new_total_trips  trip_resource_hours  \
# 6                         22          107.545                1.105
# 1                         22          107.545                2.812
# 5                          6           91.545                2.902
# 11                         4           17.857                0.848
# 0                          3           13.656                2.571
# 7                          2           87.545                2.605
# 15                         0           85.545                2.546
# 23                         0           85.545                2.278
# 22                         0           23.119                2.732
# 21                         0           85.545                2.394
# 20                         0           92.750                2.965
# 19                         0          128.110                3.452
# 18                         0           19.896                2.946
# 17                         0           69.313                3.196
# 16                         0           85.545                2.402
#
#     resource_used_hours  priority_score
# 6                24.316           1.797
# 1                61.869           3.112
# 5                17.410           2.973
# 11                3.390           1.176
# 0                 7.713           3.093
# 7                 5.210           2.623
# 15                0.000           1.942
# 23                0.000           1.000
# 22                0.000           1.396
# 21                0.000           1.111
# 20                0.000           1.638
# 19                0.000           2.096
# 18                0.000           1.993
# 17                0.000           2.101
# 16                0.000           1.787
# Total resource used (hours): 119.90833333333333
# Total added trips: 59

# %%
# ======================================================
# 13) Managerial interpretation
# ======================================================
# English:
# A simple operational impact estimate:
# If a route receives more departures, average waiting time is expected to fall.
# We use a rough proxy: average waiting time ≈ headway / 2


impact_df = lp_df.copy()

# Current and new headway proxy
impact_df["current_headway_proxy"] = impact_df["wd_service_span_min"] / impact_df["baseline_daily_trips"]
impact_df["new_headway_proxy"] = impact_df["wd_service_span_min"] / impact_df["new_total_trips"]

impact_df["estimated_wait_reduction_min"] = (
    impact_df["current_headway_proxy"] - impact_df["new_headway_proxy"]
) / 2

display(
    impact_df[[
        "ServiceNo", "Direction", "baseline_daily_trips", "new_total_trips",
        "current_headway_proxy", "new_headway_proxy", "estimated_wait_reduction_min"
    ]]
    .sort_values("estimated_wait_reduction_min", ascending=False)
    .head(15)
)
# Out:
#    ServiceNo  Direction  baseline_daily_trips  new_total_trips  \
# 11       67A          1                13.857           17.857
# 0        36B          1                10.656           13.656
# 2        858          1               162.207          162.207
# 3        518          1                58.057           58.057
# 4        502          1                61.159           61.159
# 13        24          1               105.600          105.600
# 14       966          1                92.609           92.609
# 17       160          1                69.313           69.313
# 18       70M          1                19.896           19.896
# 19        53          1               128.110          128.110
# 20        89          1                92.750           92.750
# 22      162M          1                23.119           23.119
# 24        63          1               103.442          103.442
# 1         4N          1                85.545          107.545
# 5        NR7          1                85.545           91.545
#
#     current_headway_proxy  new_headway_proxy  estimated_wait_reduction_min
# 11                 77.000             59.752                         8.624
# 0                  54.333             42.398                         5.968
# 2                   7.250              7.250                         0.000
# 3                  17.500             17.500                         0.000
# 4                  17.250             17.250                         0.000
# 13                 10.625             10.625                         0.000
# 14                 11.500             11.500                         0.000
# 17                 16.375             16.375                         0.000
# 18                 14.375             14.375                         0.000
# 19                  9.125              9.125                         0.000
# 20                 12.000             12.000                         0.000
# 22                 13.625             13.625                         0.000
# 24                 10.750             10.750                         0.000
# 1                     NaN                NaN                           NaN
# 5                     NaN                NaN                           NaN

# %% [markdown]
# ## Post-optimization route maps
#
# This section adds two map views:
# 1. Routes that receive additional trips in the optimization result.
# 2. Top 10 routes with the highest `bottleneck_score` from `route_summary`.

# %%
# ======================================================
# 14) Optimized routes map
# ======================================================
# Visualize the routes that receive additional trips after optimization.
# Route thickness reflects the optimized number of added trips.


from matplotlib import cm, colors

def build_multi_route_map(route_df, title_col=None, weight_col=None, top_n=None, zoom_start=11):
    temp_df = route_df.copy()
    if top_n is not None:
        temp_df = temp_df.head(top_n).copy()

    m = folium.Map(location=sg_center, zoom_start=zoom_start, tiles='CartoDB positron')
    n_routes = max(len(temp_df), 1)
    cmap = cm.get_cmap('tab20', n_routes)

    for idx, (_, r) in enumerate(temp_df.iterrows()):
        s_no = str(r['ServiceNo'])
        d_no = int(r['Direction'])
        subset = route_geo[
            (route_geo['ServiceNo'].astype(str) == s_no) &
            (route_geo['Direction'] == d_no)
        ].sort_values('StopSequence')

        if len(subset) < 2:
            continue

        color_hex = colors.to_hex(cmap(idx))
        points = subset[['Latitude', 'Longitude']].values.tolist()

        line_weight = 4
        if weight_col is not None and weight_col in r.index:
            try:
                line_weight = 3 + float(r[weight_col]) * 1.5
            except Exception:
                line_weight = 4

        tooltip_text = f"Service {s_no} Dir {d_no}"
        if title_col is not None and title_col in r.index:
            tooltip_text += f" | {title_col}: {r[title_col]:.2f}"

        popup_text = (
            f"ServiceNo: {s_no}<br>"
            f"Direction: {d_no}<br>"
            f"Operator: {r.get('Operator', 'N/A')}<br>"
        )
        if 'optimal_additional_trips' in r.index:
            popup_text += f"Optimal additional trips: {r['optimal_additional_trips']:.2f}<br>"
        if 'bottleneck_score' in r.index:
            popup_text += f"Bottleneck score: {r['bottleneck_score']:.2f}<br>"
        if 'route_distance_km' in r.index:
            popup_text += f"Route distance (km): {r['route_distance_km']:.2f}<br>"
        if 'n_stops' in r.index:
            popup_text += f"Stops: {int(r['n_stops'])}<br>"

        folium.PolyLine(
            points,
            weight=line_weight,
            color=color_hex,
            opacity=0.85,
            tooltip=tooltip_text,
            popup=folium.Popup(popup_text, max_width=300)
        ).add_to(m)

        # Start and end markers
        first_row = subset.iloc[0]
        last_row = subset.iloc[-1]
        folium.CircleMarker(
            location=[first_row['Latitude'], first_row['Longitude']],
            radius=4,
            color=color_hex,
            fill=True,
            fill_opacity=0.9,
            popup=f"Start: {first_row.get('Description', '')} ({first_row['BusStopCode']})"
        ).add_to(m)
        folium.CircleMarker(
            location=[last_row['Latitude'], last_row['Longitude']],
            radius=4,
            color=color_hex,
            fill=True,
            fill_opacity=0.9,
            popup=f"End: {last_row.get('Description', '')} ({last_row['BusStopCode']})"
        ).add_to(m)

    folium.LayerControl().add_to(m)
    return m

if result.success:
    optimized_routes_df = (
        lp_df[lp_df['optimal_additional_trips'] > 1e-6]
        .sort_values('optimal_additional_trips', ascending=False)
        .copy()
    )

    display(
        optimized_routes_df[[
            'ServiceNo', 'Direction', 'Operator',
            'optimal_additional_trips', 'baseline_daily_trips',
            'new_total_trips', 'bottleneck_score', 'priority_score'
        ]].head(15)
    )

    optimized_routes_map = build_multi_route_map(
        optimized_routes_df,
        title_col='optimal_additional_trips',
        weight_col='optimal_additional_trips',
        top_n=min(10, len(optimized_routes_df)),
        zoom_start=11
    )
    optimized_routes_map
else:
    print("Optimization result unavailable, so optimized route map cannot be generated.")
# Out:
#    ServiceNo  Direction Operator  optimal_additional_trips  \
# 1         4N          1     SBST                        22
# 6        67W          1     SMRT                        22
# 5        NR7          1     SMRT                         6
# 11       67A          1     SMRT                         4
# 0        36B          1      GAS                         3
# 7         2N          1     SBST                         2
#
#     baseline_daily_trips  new_total_trips  bottleneck_score  priority_score
# 1                 85.545          107.545             2.597           3.112
# 6                 85.545          107.545             2.395           1.797
# 5                 85.545           91.545             2.437           2.973
# 11                13.857           17.857             2.134           1.176
# 0                 10.656           13.656             2.722           3.093
# 7                 85.545           87.545             2.391           2.623
# /var/folders/mq/42h_20dd6550fywpscjwzb_h0000gn/T/ipykernel_32504/119209264.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', n_routes)

# %%
# ======================================================
# 15) Top 10 bottleneck routes map
# ======================================================
# Show the top 10 routes with the highest bottleneck scores on one Singapore map.


if 'route_summary' in globals() and 'bottleneck_score' in route_summary.columns:
    top10_bottleneck_df = (
        route_summary
        .sort_values('bottleneck_score', ascending=False)
        .head(10)
        .copy()
        .reset_index(drop=True)
    )

    display(
        top10_bottleneck_df[[
            'ServiceNo', 'Direction', 'Operator',
            'route_distance_km', 'n_stops',
            'one_way_trip_time_min', 'bottleneck_score'
        ]]
    )

    top10_bottleneck_map = build_multi_route_map(
        top10_bottleneck_df,
        title_col='bottleneck_score',
        weight_col=None,
        top_n=10,
        zoom_start=11
    )
    top10_bottleneck_map
else:
    print("route_summary or bottleneck_score not found. / 未找到 route_summary 或 bottleneck_score。")
# Out:
#   ServiceNo  Direction Operator  route_distance_km  n_stops  \
# 0       36B          1      GAS             40.400       56
# 1        4N          1     SBST             41.800       84
# 2       858          1     SMRT             73.500       83
# 3       518          1      GAS             59.900       91
# 4       502          1     SBST             59.600       89
# 5       NR7          1     SMRT             41.100      106
# 6       67W          1     SMRT             15.800       39
# 7        2N          1     SBST             38.700       78
# 8        5N          1     SBST             38.600       72
# 9        3N          1     SBST             38.600       72
#
#    one_way_trip_time_min  bottleneck_score
# 0                154.267             2.722
# 1                168.733             2.597
# 2                274.050             2.568
# 3                231.517             2.534
# 4                229.817             2.485
# 5                174.100             2.437
# 6                 66.317             2.395
# 7                156.300             2.391
# 8                153.867             2.305
# 9                153.867             2.305
# /var/folders/mq/42h_20dd6550fywpscjwzb_h0000gn/T/ipykernel_32504/119209264.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab20', n_routes)

# %%
# ======================================================
# 16) Export new route maps
# ======================================================
# Save the new route maps to HTML for presentation and sharing.

if 'map_output_dir' not in globals():
    map_output_dir = Path('bus_outputs')
    map_output_dir.mkdir(exist_ok=True)

if 'optimized_routes_map' in globals():
    optimized_routes_html = map_output_dir / 'singapore_optimized_routes_map.html'
    optimized_routes_map.save(str(optimized_routes_html))
    print('Saved:', optimized_routes_html)

if 'top10_bottleneck_map' in globals():
    top10_bottleneck_html = map_output_dir / 'singapore_top10_bottleneck_routes_map.html'
    top10_bottleneck_map.save(str(top10_bottleneck_html))
    print('Saved:', top10_bottleneck_html)
# Out:
# Saved: bus_outputs/singapore_optimized_routes_map.html
# Saved: bus_outputs/singapore_top10_bottleneck_routes_map.html

# %%
# ======================================================
# 14) Export outputs
# ======================================================
#  Save the route summary and ILP results for report writing.


output_dir = Path("./bus_om_outputs")
output_dir.mkdir(exist_ok=True)

route_summary.to_csv(output_dir / "route_summary.csv", index=False)
lp_df.to_csv(output_dir / "lp_optimization_results.csv", index=False)

print("Files saved to:", output_dir.resolve())
# Out:
# Files saved to: /Users/huanghaojie/Downloads/bus_om_outputs
